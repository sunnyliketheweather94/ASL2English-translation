# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2

import os
import sys
import glob

# %%
current_dir = os.getcwd()
videos_dir = os.path.join(current_dir, 'rwth-boston-104/videoBank/camera0/')
labels_dir = os.path.join(current_dir, 'rwth-boston-104/corpus/')

# %%
# obtain the names of the different videos and the corresponding translations
# then sort them according to video number (use this later for dividing into train/dev/test)
# and save the names/translations to a csv file
os.chdir(labels_dir)

train = pd.read_csv('train.sentences.pronunciations.multi.translations.csv', sep = ';')
test = pd.read_csv('test.sentences.multi.translations.csv', sep = ';')

names = train['video'].append(test['video'], ignore_index = True)
labels = train['translation'].append(test['translation'], ignore_index = True)

names = [int(i.split('_')[0]) for i in names]

zipped_list = zip(names, labels)
sorted_zip = sorted(zipped_list, key = lambda x: x[0])

names, labels = [list(x) for x in zip(*sorted_zip)]

df = pd.DataFrame(sorted_zip, columns = ['Video', 'Translations'])
print(df.head())

os.chdir('..')
os.chdir('..') # need to save the csv file in the Data folder
path = os.path.join(os.getcwd(), 'labels.csv')

df.to_csv(path, index = False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-8a0258c99398> in <module>
#       2 # then sort them according to video number (use this later for dividing into train/dev/test)
#       3 # and save the names/translations to a csv file
# ----> 4 os.chdir(labels_dir)
#       5
#       6 train = pd.read_csv('train.sentences.pronunciations.multi.translations.csv', sep = ';')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/cs230_project/rwth-boston-104/corpus/'

# %%
x = ['001_', '004_', '021_']
y = [int(i.split('_')[0]) for i in x]
print(y)
# Out:
# [1, 4, 21]

# %%
# extract frames from a given video
def FrameCapture(name, path, video_dir): 
    '''
    name: the name of the video being processed
    path: absolute path of the video being processed
    video_dir: directory of the video
    '''
    vid = cv2.VideoCapture(path) # get the video
    
    current_dir = os.path.join(video_dir, name) # get the path to the directory to store the frames
    
    try:
        # if the folder for containing the frames doesn't exist..
        # create it and change the directory to it
        if not os.path.exists(current_dir):
            os.mkdir(current_dir)
            os.chdir(current_dir)
    
            current_frame = 1
            success = True

            while(success):
                # read in the video
                success, frame = vid.read()

                # if the reading was successful
                # then save the frame to file
                # if the video was named 001_0.mpg, 
                # then the frame image is saved as 001_001.jpg 
                # where 1 is the first frame, etc.
                if success:
                    file_name = name + '_' + str(current_frame).zfill(3) + '.jpg'
                    cv2.imwrite(file_name, frame)

                else:
                    break

                current_frame += 1
    
    except:
        print('Error - cannot create new directory')
    
    vid.release()
    cv2.destroyAllWindows()

# %%
for i in range(1, 202):
    num_str = str(i)
    filled_num = num_str.zfill(3)
    
    names.append(filled_num)

    path = os.path.join(videos_dir, filled_num + '_0.mpg')

    # extract frames for each video and store the frames in the corresponding directory
    FrameCapture(filled_num, path, videos_dir)

# %%
# trial of seeing what numbers to use for the cropping
os.chdir(os.path.join(videos_dir, '135'))
print(os.getcwd())

img = cv2.imread('135_054.jpg')
img_cropped = img[9:240, 3:330]

plt.imshow(img_cropped)
# Out:
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/rwth-boston-104/videoBank/camera0/135

# %%
os.chdir('/Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/')

path_list = []

for folders, subfolders, _ in os.walk(os.getcwd()):
    for s in subfolders:
        path_list.append(os.path.join(folders, s))
        
for item in path_list:
    print(item)

for path in path_list:
    os.chdir(path)
    
    for _, _, files in os.walk(os.getcwd()):
        for f in files:
            if f.endswith('.jpg'):
                img = cv2.imread(f)
                img_cropped = img[9:240, 3:330]

                name = f.split('.')[0] + '_cropped.jpg'

                cv2.imwrite(name, img_cropped)
                cv2.destroyAllWindows()
# Out:
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/rwth-boston-104
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/.ipynb_checkpoints
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/rwth-boston-104/lm
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/rwth-boston-104/corpus
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/rwth-boston-104/handpositions
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/rwth-boston-104/videoBank
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/rwth-boston-104/lexicon
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/rwth-boston-104/overview
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/rwth-boston-104/corpus/001
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/rwth-boston-104/videoBank/camera0
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/rwth-boston-104/overview/images
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/rwth-boston-104/overview/record-details-html
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/rwth-boston-104/overview/images/thumbnail
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/rwth-boston-104/overview/images/orig
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/rwth-boston-104/overview/record-details-html/images
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/135
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/132
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/104
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/103
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/168
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/157
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/150
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/159
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/166
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/192
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/195
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/161
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/102
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/105
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/133
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/134
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/160
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/194
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/158
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/193
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/167
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/151
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/169
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/156
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/024
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/023
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/015
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/012
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/079
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/046
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/041
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/048
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/077
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/083
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/084
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/070
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/013
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/014
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/022
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/025
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/071
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/085
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/049
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/082
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/076
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/040
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/078
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/047
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/065
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/091
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/096
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/062
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/054
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/053
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/098
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/038
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/007
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/009
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/036
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/031
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/052
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/099
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/055
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/063
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/097
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/090
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/064
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/030
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/008
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/037
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/001
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/039
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/006
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/174
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/180
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/187
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/173
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/145
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/142
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/189
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/129
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/116
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/111
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/118
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/127
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/120
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/143
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/188
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/144
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/172
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/186
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/181
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/175
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/121
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/119
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/126
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/110
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/128
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/117
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/198
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/153
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/154
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/196
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/162
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/165
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/191
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/131
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/136
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/109
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/100
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/107
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/138
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/190
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/164
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/163
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/197
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/155
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/199
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/152
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/106
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/139
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/101
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/137
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/108
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/130
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/089
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/042
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/045
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/087
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/073
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/074
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/080
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/020
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/027
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/018
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/011
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/016
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/029
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/081
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/075
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/072
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/086
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/044
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/088
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/043
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/017
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/028
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/010
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/026
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/019
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/021
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/003
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/004
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/200
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/032
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/035
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/095
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/061
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/066
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/092
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/059
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/050
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/057
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/068
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/034
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/033
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/201
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/005
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/002
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/056
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/069
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/051
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/093
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/067
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/058
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/060
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/094
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/112
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/115
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/123
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/124
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/184
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/170
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/177
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/183
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/148
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/141
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/146
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/179
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/125
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/122
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/114
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/113
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/147
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/178
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/140
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/182
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/176
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/149
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/171
# /Users/sunnyshah/Desktop/Spring 2020/CS 230/Project/Data/Processed Data/185
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-19776ba1f811> in <module>
#      17             if f.endswith('.jpg'):
#      18                 img = cv2.imread(f)
# ---> 19                 img_cropped = img[9:240, 3:330]
#      20
#      21                 name = f.split('.')[0] + '_cropped.jpg'
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# removes all the uncropped images from the folder 'Processed Data'
os.chdir(os.path.join(videos_dir, 'Processed Data'))

path_list = []

for folders, subfolders, _ in os.walk(os.getcwd()):
    for s in subfolders:
        path_list.append(os.path.join(folders, s))

for path in path_list:
    os.chdir(path)
    
    for _, _, files in os.walk(os.getcwd()):
        for f in files:
            if (not f.endswith('_cropped.jpg')) and (f.endswith('.jpg')):
                os.remove(f)

# %%
# renames all the files '*_cropped.jpg' as '*.jpg'
os.chdir(os.path.join(videos_dir, 'Processed Data'))

path_list = []

for folders, subfolders, _ in os.walk(os.getcwd()):
    for s in subfolders:
        path_list.append(os.path.join(folders, s))

for path in path_list:
    os.chdir(path)
    
    for _, _, files in os.walk(os.getcwd()):
        for f in files:
            if f.endswith('.jpg'):
                name = f.split('_')
                new_name = name[0] + '_' + name[1] + '.jpg'
                
                source = os.path.join(os.getcwd(), f)
                destination = os.path.join(os.getcwd(), new_name)
                os.rename(source, destination)
