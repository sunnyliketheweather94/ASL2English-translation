# %%
# !git clone https://github.com/skitiz/thesis.git
# Out:
# Cloning into 'thesis'...
# remote: Enumerating objects: 52, done.
# remote: Total 52 (delta 0), reused 0 (delta 0), pack-reused 52
# Unpacking objects: 100% (52/52), done.

# %%
# %ls
# Out:
# sample_data/  thesis/

# %%
# %cd thesis
# Out:
# /content/thesis

# %%
# !cat requirements.txt
# Out:
# cat: requirements.txt: No such file or directory

# %%
# !pip install tensorflow-gpu==1.13.2
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/0f/39/bdd75b08a6fba41f098b6cb091b9e8c7a80e1b4d679a581a0ccd17b10373/tensorboard-1.13.1-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/bb/48/13f49fc3fa0fdf916aa1419013bb8f2ad09674c275b4046d5ee669a46873/tensorflow_estimator-1.13.0-py2.py3-none-any.whl
# ...
# ERROR: tensorflow 2.2.0rc4 has requirement tensorboard<2.3.0,>=2.2.0, but you'll have tensorboard 1.13.1 which is incompatible.
# ERROR: tensorflow 2.2.0rc4 has requirement tensorflow-estimator<2.3.0,>=2.2.0, but you'll have tensorflow-estimator 1.13.0 which is incompatible.
# ...
#   Found existing installation: tensorboard 2.2.1
#     Uninstalling tensorboard-2.2.1:
#       Successfully uninstalled tensorboard-2.2.1
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
# ...

# %%
# !python architecture.py
# Out:
# Traceback (most recent call last):
#   File "architecture.py", line 1, in <module>
#     import tflearn
# ModuleNotFoundError: No module named 'tflearn'

# %%
# !pip install tflearn
# Out:
# ...
#      |████████████████████████████████| 102kB 2.8MB/s
# ...
#   Created wheel for tflearn: filename=tflearn-0.3.2-cp36-none-any.whl size=128208 sha256=b3d1e2ba1afc2b221da8d6eaa7f0c0f79bb313fa5340277024dbf47c009c6fc3
#   Stored in directory: /root/.cache/pip/wheels/d0/f6/69/0ef3ee395aac2e5d15d89efd29a9a216f3c27767b43b72c006
# Successfully built tflearn
# ...

# %%
# !python architecture.py
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
